# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler

# %%
data = pd.DataFrame(None)
for i in range(4):
    
    file_name = './{}.csv'.format(i)
    frame = pd.read_csv(file_name, delimiter=';')
    
    data = pd.concat([data, frame], ignore_index=True)

# %%
data.head()
# Out:
#               datetime  Accelerometer1RMS  ...  anomaly  changepoint
# 0  2020-03-09 10:14:33           0.026588  ...      0.0          0.0
# 1  2020-03-09 10:14:34           0.026170  ...      0.0          0.0
# 2  2020-03-09 10:14:35           0.026199  ...      0.0          0.0
# 3  2020-03-09 10:14:36           0.026027  ...      0.0          0.0
# 4  2020-03-09 10:14:37           0.026290  ...      0.0          0.0
#
# [5 rows x 11 columns]

# %%
data.shape
# Out:
# (17012, 11)

# %%
def plot(data: pd.DataFrame, stream_num: list, 
         start_seq: int, end_seq: int, ls = '--', marker=False):

    n_streams = len(stream_num)
    fig, axes = plt.subplots(n_streams, 1, figsize=(20, n_streams*4))

    plot_data = data.loc[start_seq:end_seq, :]
    for i, stream in enumerate(stream_num):
        axes[i].plot(plot_data.index, plot_data.iloc[:,  stream], 
                     color='grey', ls=ls, lw=1.5, zorder=1)

        anomaly = [0, 1]
        sizes   = [20, 20]
        markers = ['o', 'D']
        colors  = ['green', 'red']

        if marker == False:
            markers = ['', '']

        for a, s, m, c in zip(anomaly, sizes, markers, colors):
            axes[i].scatter(plot_data.loc[plot_data.anomaly == a, :].index, 
                            plot_data.loc[plot_data.anomaly == a, :].iloc[:, stream].values, 
                            marker=m, s=s, color=c, zorder = 2)

        axes[i].set_xlabel('Time', fontsize = 15)
        axes[i].set_ylabel('Stream №{}'.format(stream), fontsize = 15)
        axes[i].grid(color='blue', which='major', linestyle=':',
                     linewidth=0.5)

# %%
start_seq, end_seq = 0, data.shape[0]
plot(data, [1, 2, 3, 4, 5, 6, 7, 8], start_seq, end_seq,  ls='--', marker=True)

# %%
adfuller(data.values[:, 1], autolag='AIC')
# Out:
# (-5.012368256253572,
#  2.097569996408074e-05,
#  42,
#  16969,
#  {'1%': -3.4307354257464486,
#   '10%': -2.5668606691930673,
#   '5%': -2.861710342957916},
#  -219617.760743946)

# %%
adfuller(data.values[:, 2], autolag='AIC')
# Out:
# (-10.334211128354461,
#  2.7912327540600187e-18,
#  34,
#  16977,
#  {'1%': -3.430735244096429,
#   '10%': -2.5668606264628115,
#   '5%': -2.86171026268099},
#  -193203.7405306765)

# %%
adfuller(data.values[:, 3], autolag='AIC')
# Out:
# (-21.806959524090757,
#  0.0,
#  31,
#  16980,
#  {'1%': -3.4307351760218077,
#   '10%': -2.566860610449347,
#   '5%': -2.8617102325966464},
#  112961.75964731706)

# %%
adfuller(data.values[:, 4], autolag='AIC')
# Out:
# (-125.55048172191378,
#  0.0,
#  0,
#  17011,
#  {'1%': -3.4307344739902277,
#   '10%': -2.566860445307651,
#   '5%': -2.86170992234649},
#  2184.268960278361)

# %%
adfuller(data.values[:, 5], autolag='AIC')
# Out:
# (-3.793635682563802,
#  0.002973105622741925,
#  24,
#  16987,
#  {'1%': -3.4307350172745448,
#   '10%': -2.566860573106596,
#   '5%': -2.861710162441172},
#  -28632.88796658782)

# %%
adfuller(data.values[:, 6], autolag='AIC')
# Out:
# (-2.12015121139132,
#  0.23648927495345157,
#  35,
#  16976,
#  {'1%': -3.4307352667933175,
#   '10%': -2.566860631801891,
#   '5%': -2.8617102727114676},
#  -126132.02930160161)

# %%
adfuller(data.values[:, 7], autolag='AIC')
# Out:
# (-130.7138950651906,
#  0.0,
#  0,
#  17011,
#  {'1%': -3.4307344739902277,
#   '10%': -2.566860445307651,
#   '5%': -2.86170992234649},
#  134602.64925655595)

# %%
adfuller(data.values[:, 8], autolag='AIC')
# Out:
# (-6.164215741416442,
#  7.053890023502081e-08,
#  27,
#  16984,
#  {'1%': -3.4307350852930605,
#   '10%': -2.5668605891068625,
#   '5%': -2.861710192500722},
#  22457.476480574634)

# %%
preproces_data = data.iloc[:, 1:9].diff()
preproces_data['anomaly'] = data.loc[1:, 'anomaly']

new_data = preproces_data.drop(index=0)

# %%
new_data.head()
# Out:
#    Accelerometer1RMS  Accelerometer2RMS  ...  Volume Flow RateRMS  anomaly
# 1          -0.000418           0.000341  ...                  0.0      0.0
# 2           0.000029          -0.001034  ...                  0.0      0.0
# 3          -0.000172           0.000222  ...                  0.0      0.0
# 4           0.000263           0.000632  ...                  0.0      0.0
# 5          -0.000307          -0.000281  ...                  0.0      0.0
#
# [5 rows x 9 columns]

# %%
new_data.shape, data.shape
# Out:
# ((17011, 9), (17012, 11))

# %%
start_seq, end_seq = 0, new_data.shape[0]
plot(new_data, [0, 1, 2, 3, 4, 5, 6, 7], start_seq, end_seq,  ls='-', marker=False)

# %%
new_data.shape
# Out:
# (17011, 9)

# %%
TRAIN_SAMPLES = 5000
scaler = StandardScaler().fit(new_data.values[:TRAIN_SAMPLES, :-1])

# %%
train_data = scaler.transform(new_data.values[:TRAIN_SAMPLES, :-1])
test_data  = scaler.transform(new_data.values[TRAIN_SAMPLES:, :-1])

# %%
start_seq, end_seq = 0, TRAIN_SAMPLES
fig, axes = plt.subplots(8,1, figsize=(16,16))


for i in range(8):
    axes[i].plot(np.arange(start_seq,end_seq), train_data[start_seq:end_seq,  i], 
                 color='grey', ls='-', lw=1.5, zorder=1)

    axes[i].set_xlabel('Time', fontsize = 15)
    axes[i].set_ylabel('Value', fontsize = 15)
    axes[i].grid(color='blue', which='major', linestyle=':',linewidth=0.5)

# %%
class NominalDataset(Dataset):

	def __init__(self, x: np.array, seq_length: int, step: int):
		super(NominalDataset, self).__init__()

		if not isinstance(x, np.ndarray):
			raise Exception("X isn't numpy.ndarray ")

		self.n_samples = x.shape[0] - step * (seq_length - 1) - 1
		self.data = [
			(
				torch.from_numpy(x[i:i+(seq_length*step):step, :].astype(np.float32)),
				torch.from_numpy(x[i+((seq_length-1)*step)+1, :].astype(np.float32))
			)

			for i in range(self.n_samples)
		]
	

	def __getitem__(self, index: int) -> tuple:
		return self.data[index][0], self.data[index][1]


	def __len__(self) -> int:
		return self.n_samples

# %%
class Encoder(nn.Module):

	def __init__(self, input_size: int, hidden_size: int, 
				num_layers: int, seq_length: int, z_size: int):
		super(Encoder, self).__init__()

		self.z_size = z_size
		self.num_layers = num_layers
		self.hidden_size = hidden_size

		self.lstm = nn.LSTM(input_size, hidden_size, num_layers, 
							batch_first=True, bidirectional=True)

		# mu
		self.m_layers = nn.ModuleList([

			nn.Sequential(

				nn.Linear(2*hidden_size, hidden_size),
				nn.LeakyReLU(0.1),
				nn.Linear(hidden_size, z_size)

			)

			for _ in range(seq_length)
		])

		# logvar
		self.v_layers = nn.ModuleList([ 

			nn.Sequential(

				nn.Linear(2*hidden_size, hidden_size),
				nn.LeakyReLU(0.1),
				nn.Linear(hidden_size, z_size)

			)

			for _ in range(seq_length)
			])


	def forward(self, x: torch.tensor) -> torch.tensor:

		h0 = torch.zeros(2 * self.num_layers, x.size(0), self.hidden_size)
		c0 = torch.zeros(2 * self.num_layers, x.size(0), self.hidden_size)

		output, _ = self.lstm(x, (h0, c0))
		z = torch.zeros(x.size(0), x.size(1), self.z_size)

		mu = torch.zeros(x.size(0), x.size(1), self.z_size)
		logvar = torch.zeros(x.size(0), x.size(1), self.z_size)

		for indx, (m, v) in enumerate(zip(self.m_layers, self.v_layers)):
			mu[:, indx, :]  = m(output[:, indx, :])
			logvar[:, indx, :] = F.softplus(v(output[:, indx, :]))

			# reparametrazation trick
			std = torch.exp(logvar[:, indx, :] / 2)
			eps = torch.randn_like(std)

			z[:, indx, :] = mu[:, indx, :] + eps*std

		return z, mu, logvar

# %%
class Decoder(nn.Module):

	def __init__(self, z_size:  int, hidden_size: int, 
				num_layers: int, seq_length: int, output_size: int):
		super(Decoder, self).__init__()

		self.num_layers = num_layers
		self.output_size = output_size
		self.hidden_size = hidden_size

		self.lstm = nn.LSTM(z_size, hidden_size, num_layers, 
							batch_first=True, bidirectional=True)


		self.layers = nn.ModuleList([
			nn.Sequential(

				nn.Linear(hidden_size * 2, hidden_size),
				nn.LeakyReLU(0.2)

			)

			for _ in range(seq_length)

		])


		self.h2 = output_size * 2
		self.h4 = output_size * 4

		self.m = nn.Sequential(

			nn.Flatten(),
			nn.Linear(
				seq_length * hidden_size, 
				seq_length * hidden_size, bias=False
			),
			nn.LeakyReLU(0.2),
			nn.BatchNorm1d(seq_length * hidden_size),

			nn.Linear(
				seq_length * hidden_size, 
				seq_length * self.h4
			),
			nn.LeakyReLU(0.2),
		)


		# mu
		self.m_layers = nn.ModuleList([
			nn.Linear(self.h4, output_size) for _ in range(seq_length)
		])

		# logvar
		self.v_layers = nn.ModuleList([
			nn.Linear(self.h4, output_size) for _ in range(seq_length)
		])


	def forward(self, z: torch.tensor) -> torch.tensor:

		h0 = torch.zeros(2*self.num_layers, z.size(0), self.hidden_size)
		c0 = torch.zeros(2*self.num_layers, z.size(0), self.hidden_size)

		output, _ = self.lstm(z, (h0, c0))
		hidden1 = torch.zeros(z.size(0), z.size(1), self.hidden_size)

		for indx, m in enumerate(self.layers):
			hidden1[:, indx, :] = m(output[:, indx, :])

		hidden2 = self.m(hidden1)
		hidden2 = hidden2.view(z.size(0), z.size(1), -1)

		mu = torch.zeros(z.size(0), z.size(1), self.output_size)
		logvar = torch.zeros(z.size(0), z.size(1), self.output_size)


		for indx, (m, v) in enumerate(zip(self.m_layers, self.v_layers)):
			mu[:, indx, :]  = m(hidden2[:, indx, :])
			logvar[:, indx, :] = F.softplus(v(hidden2[:, indx, :]))

		return mu, logvar

# %%
class VAE(nn.Module):

	def __init__(self, encoder, decoder):
		super(VAE, self).__init__()

		self.enc = encoder
		self.dec = decoder

	def forward(self, x: torch.tensor) -> tuple:

		z, z_mu, z_logvar = self.enc(x)
		x_mu, x_logvar = self.dec(z)

		return x_mu, x_logvar, z_mu, z_logvar

# %%
# Hyperparameters

INPUT_SIZE  = 8
OUTPUT_SIZE = 8
Z_SIZE = 3

STEP = 1
SEQ_LENGTH = 100
BATCH_SIZE = 64

# %%
# Dataset
dataset = NominalDataset(train_data, seq_length=SEQ_LENGTH, step=STEP)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
# part of VAE
encoder = Encoder(
    
    input_size=INPUT_SIZE, 
    hidden_size=80, 
    num_layers=1, 
    seq_length=SEQ_LENGTH, 
    z_size=Z_SIZE

)

decoder = Decoder(
    
    z_size=Z_SIZE, 
    hidden_size=80, 
    num_layers=1, 
    seq_length=SEQ_LENGTH, 
    output_size=OUTPUT_SIZE

)

model = VAE(encoder, decoder)

# %%
def vae_loss(x_mu, x_logvar, x, mu, logvar, landa = 1):
    
    likelihood = torch.mean(0.5 * (x - x_mu) ** 2 / torch.exp(x_logvar) + \
                            torch.log(torch.sqrt(2*np.pi*torch.exp(x_logvar))), dim=0)
    
    KLD = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp(), dim=0)
    
    return torch.sum(likelihood), torch.sum(KLD)

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[12,17], gamma=0.1)

# %%
LANDA = 1
for epoch in range(10):
    
    mu_values  = torch.tensor([])
    var_values = torch.tensor([])    
        
    KLDLosses = torch.tensor([])
    likelihoodLosses = torch.tensor([])

    
    for sample, target in dataloader:
        
        x_mu, x_logvar, z_mu, z_logvar = model(sample)

        mu_values   = torch.cat((mu_values,  torch.mean(z_mu, dim=2)), dim=0)
        var_values  = torch.cat((var_values, torch.mean(z_logvar.exp(), dim=2)), dim=0)
        
    
        #VAE train
        
        likelihood, KLD = vae_loss(x_mu, x_logvar, sample, z_mu, z_logvar, LANDA)
        loss = likelihood + KLD

        KLDLosses = torch.cat(
            (KLDLosses, torch.unsqueeze(KLD, 0)), dim=0
        )
        
        likelihoodLosses = torch.cat(
            (likelihoodLosses, torch.unsqueeze(likelihood, 0)), dim=0
        )

        model.zero_grad()
        loss.backward()

        # cliping
        torch.nn.utils.clip_grad_norm_(
            model.parameters(), max_norm=1, norm_type=2
        )

        optimizer.step()
    
    scheduler.step()
    print("""    \nEpoch {}: LikeliHood: {:.5f}, KLD: {:.5f}
    Mean: [{}\n\t   {}] 
    Var:  [{}\n\t   {}]""".format(epoch, torch.mean(likelihoodLosses), torch.mean(KLDLosses),
                                  torch.mean(mu_values, dim=0)[:5].detach(), torch.mean(mu_values, dim=0)[-5:].detach(),
                                  torch.mean(var_values, dim=0)[:5].detach(), torch.mean(var_values, dim=0)[-5:].detach()
    ))

# %%
from torch.distributions.multivariate_normal import MultivariateNormal

# %%
# Dataset
dataset = NominalDataset(test_data, seq_length=SEQ_LENGTH, step=STEP)
dataloader = DataLoader(dataset, batch_size=256, shuffle=False)

# %%
mz = MultivariateNormal(torch.zeros(Z_SIZE), torch.eye(Z_SIZE))

# %%
model.eval()

probx_data   = np.empty(test_data.shape[0])
probz_data   = np.empty(test_data.shape[0])
stream_data = np.empty(test_data.shape)

for i, (sample, _) in enumerate(dataloader):
    x_mu, x_logvar, z_mu, z_logvar = model(sample)
    
    n = sample.size(0)
    for j in range(n):
        index = i * n + j

        mx = MultivariateNormal(
            x_mu[j, -1, :], 
            torch.diag(torch.exp(x_logvar[j, -1, :]))
        )
        
        eps = torch.randn_like(z_mu[j, -1, :])
        z = z_mu[j, -1, :] + eps * torch.exp(z_logvar[j, -1, :] / 2)
    
        
        probx_data[index]   = mx.log_prob(sample[j, -1, :]).detach().numpy()
        probz_data[index]   = mz.log_prob(z).detach().numpy()
        stream_data[index, :] = x_mu[j, -1, :].detach().numpy()
        #stream_data[index, :] = mx.sample().detach().numpy()

model.train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-29a09b25c8db> in <module>()
#       6
#       7 for indx, (sample, _) in enumerate(dataset):
# ----> 8     x_mu, x_logvar, z_mu, z_logvar = model(sample.unsqueeze(0))
#       9
#      10     mx = MultivariateNormal(x_mu[0, -1, :], torch.diag(torch.exp(x_logvar[0, -1, :])))
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-28-c2b39e3d6a2f> in forward(self, x)
#       9         def forward(self, x: torch.tensor) -> tuple:
#      10
# ---> 11                 z, z_mu, z_logvar = self.enc(x)
#      12                 x_mu, x_logvar = self.dec(z)
#      13
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-26-8cafb400bb36> in forward(self, x)
#      53
#      54                 for indx, (m, v) in enumerate(zip(self.m_layers, self.v_layers)):
# ---> 55                         mu[:, indx, :]  = m(output[:, indx, :])
#      56                         logvar[:, indx, :] = F.softplus(v(output[:, indx, :]))
#      57
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     872         for hook in itertools.chain(
#     873                 _global_forward_pre_hooks.values(),
# --> 874                 self._forward_pre_hooks.values()):
#     875             result = hook(self, input)
#     876             if result is not None:
#
# KeyboardInterrupt:

# %%
plot_data = test_data[SEQ_LENGTH - 1:, :]
probx_data = probx_data[: 1 - SEQ_LENGTH]
probz_data = probz_data[: 1 - SEQ_LENGTH]
stream_data = stream_data[: 1 - SEQ_LENGTH, :]

# %%
data.shape, plot_data.shape, probx_data.shape, probz_data.shape, stream_data.shape

# %%
start_seq, end_seq = 0, 550
#start_seq, end_seq = 0, stream_data.shape[0]
fig, axes = plt.subplots(18, 1, figsize=(16,48))

axes[16].plot(np.arange(start_seq, end_seq), probz_data[start_seq:end_seq], 
                 color='red', ls='-', lw=1.5, zorder=2, label='LogProb')
axes[16].grid(color='blue', which='major', linestyle=':',linewidth=0.5)

axes[17].plot(np.arange(start_seq, end_seq), probx_data[start_seq:end_seq], 
                 color='red', ls='-', lw=1.5, zorder=2, label='LogProb')
axes[17].grid(color='blue', which='major', linestyle=':',linewidth=0.5)


for i in range(8):
    axes[2*i].plot(np.arange(start_seq, end_seq), plot_data[start_seq:end_seq,  i], 
                   color='blue', ls='-', lw=1.5, zorder=1, label='Real')
    
    axes[2*i].plot(np.arange(start_seq, end_seq), stream_data[start_seq:end_seq,  i], 
                   color='red', ls='-', lw=1.5, zorder=2, label='Reconstruction')
    
    
    error_data = np.abs(plot_data[start_seq:end_seq, i] - stream_data[start_seq:end_seq, i])
    axes[2*i+1].plot(np.arange(start_seq, end_seq), error_data,
                 color='grey', ls='-', lw=1.5, zorder=1)
    


                                                                       
    
    
    #axes[3*i].set_ylabel('Real', fontsize = 15)
    #axes[3*i+1].set_ylabel('Recon', fontsize = 15)
    axes[2*i].set_ylabel('Values', fontsize = 15)
    axes[2*i+1].set_ylabel('Error', fontsize = 15)
    
#     axes[3*i+1].set_ylim(np.min(data[start_seq:,  i]) - 2 , 
#                          np.max(data[start_seq:,  i]) + 2)

    #axes[3*i].set_ylim(-5, 5)
    #axes[3*i+1].set_ylim(-5, 5)
    #axes[3*i+2].set_ylim(0, 10)
    
    for j in range(2):
        
        #axes[3*i+j].set_xlabel('Time', fontsize = 15)
        axes[2*i+j].grid(color='blue', which='major', linestyle=':',linewidth=0.5)

# %%
from spot import biSPOT
import matplotlib.pyplot as plt

# %%
n_init = 200
spot_data = probx_data[n_init:]
spot_init_data = probx_data[:n_init]

# %%
q = 1e-5 	# risk parameter
d = 200     # depth parameter

# %%
s = biSPOT(q)     	# biDSPOT object
s.fit(spot_init_data, spot_data) 	# data import
s.initialize() 	  		# initialization step
# Out:
# Initial threshold : {'up': -4.947279930114746, 'down': -11.807259559631348}
# Number of peaks : {'up': 3, 'down': 4}
# Grimshaw maximum log-likelihood estimation ... [done]
# 	          Parameters               Upper               Lower
# 	------------------------------------------------------------
# 	                   γ               -0.08                0.00
# 	                   σ                0.03               27.50
# 	          likelihood                7.90               17.26
# 	    Extreme quantile               -4.79             -220.79
# 	------------------------------------------------------------

# %%
results = s.run()    	# run
# Out:
# 100%|██████████| 400/400 [00:02<00:00, 173.15it/s]

# %%
s.plot(results)
# Out:
# [<matplotlib.lines.Line2D at 0x7fc5e17f8490>,
#  <matplotlib.lines.Line2D at 0x7fc5e17b3ad0>,
#  <matplotlib.lines.Line2D at 0x7fc5e17b3350>,
#  <matplotlib.collections.PathCollection at 0x7fc5e17b3b50>]

# %%
anomalies = data.values[(TRAIN_SAMPLES+SEQ_LENGTH + n_init):, -1]
anomalies.shape, len(results['upper_thresholds'])
# Out:
# ((400,), 400)

# %%
pred_anomalies = np.zeros_like(anomalies)
pred_anomalies[results['alarms']] = 1

# %%
df = pd.DataFrame({'pred': pred_anomalies, 'real': anomalies})

# %%
df.loc[(df.pred == 1) | (df.real == 1), :]
# Out:
#      pred  real
# 214   0.0   1.0
# 216   0.0   1.0
# 358   1.0   0.0
# 360   1.0   1.0
# 361   1.0   1.0
# 362   1.0   1.0
# 363   1.0   0.0
# 386   1.0   0.0
# 387   1.0   0.0
# 397   1.0   0.0
# 399   1.0   0.0
