# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler

# %%
file_name = 'nyc_taxi.csv'
data = pd.read_csv('../data/{}'.format(file_name), header=None)

# %%
data.head()
# Out:
#                      0      1    2  3
# 0  2014-07-01 00:00:00  10844    0  1
# 1  2014-07-01 00:30:00   8127   30  1
# 2  2014-07-01 01:00:00   6210   60  1
# 3  2014-07-01 01:30:00   4656   90  1
# 4  2014-07-01 02:00:00   3820  120  1

# %%
data.shape
# Out:
# (17520, 4)

# %%
start_seq, end_seq = 0, 1000
#start_seq, end_seq = 0, data.shape[0]
fig, axes = plt.subplots(2,1, figsize=(16,10))


for i in range(2):
    axes[i].plot(np.arange(start_seq,end_seq), data.iloc[start_seq:end_seq,  i+1], 
                 color='grey', ls='-', lw=1.5, zorder=1)

    axes[i].set_xlabel('Time', fontsize = 15)
    axes[i].set_ylabel('Value', fontsize = 15)
    axes[i].grid(color='blue', which='major', linestyle=':',linewidth=0.5)

# %% [markdown]
# ### Check stationarity wth origin data

# %%
adfuller(data.values[:, 1], autolag='AIC')
# Out:
# (-7.710322672335624,
#  1.2689436298447364e-11,
#  44,
#  17475,
#  {'1%': -3.4307242638530675,
#   '5%': -2.861705410152796,
#   '10%': -2.5668580435332715},
#  292414.5410851413)

# %%
adfuller(data.values[:, 2], autolag='AIC')
# Out:
# (-161.52319851972118,
#  0.0,
#  44,
#  17475,
#  {'1%': -3.4307242638530675,
#   '5%': -2.861705410152796,
#   '10%': -2.5668580435332715},
#  215196.1087532755)

# %%
preproces_data = data.loc[:, 1:2].diff()
new_data = preproces_data.drop(index=0)

# %%
new_data.head()
# Out:
#         1     2
# 1 -2717.0  30.0
# 2 -1917.0  30.0
# 3 -1554.0  30.0
# 4  -836.0  30.0
# 5  -947.0  30.0

# %%
new_data.shape, data.shape
# Out:
# ((17519, 2), (17520, 4))

# %% [markdown]
# ### Check stationarity wth preproces data

# %%
adfuller(new_data.values[:, 0], autolag='AIC')
# Out:
# (-67.24769653603155,
#  0.0,
#  44,
#  17474,
#  {'1%': -3.4307242852745428,
#   '5%': -2.8617054196196627,
#   '10%': -2.566858048572343},
#  292271.794954892)

# %%
adfuller(new_data.values[:, 1], autolag='AIC')
# Out:
# (-96.28358545466655,
#  0.0,
#  44,
#  17474,
#  {'1%': -3.4307242852745428,
#   '5%': -2.8617054196196627,
#   '10%': -2.566858048572343},
#  229120.34428588464)

# %%
start_seq, end_seq = 0, 1000
#start_seq, end_seq = 0, data.shape[0]
fig, axes = plt.subplots(2,1, figsize=(16,10))


for i in range(2):
    axes[i].plot(np.arange(start_seq,end_seq), new_data.iloc[start_seq:end_seq,  i], 
                 color='grey', ls='-', lw=1.5, zorder=1)

    axes[i].set_xlabel('Time', fontsize = 15)
    axes[i].set_ylabel('Value', fontsize = 15)
    axes[i].grid(color='blue', which='major', linestyle=':',linewidth=0.5)

# %% [markdown]
# ### Scale Data

# %%
TRAIN_SAMPLES = 800
scaler = StandardScaler().fit(new_data.values[:TRAIN_SAMPLES, :])

# %%
train_data = scaler.transform(new_data.values[:TRAIN_SAMPLES, :])
test_data  = scaler.transform(new_data.values[TRAIN_SAMPLES:, :])

# %%
start_seq, end_seq = 0, TRAIN_SAMPLES
fig, axes = plt.subplots(2,1, figsize=(16,10))


for i in range(2):
    axes[i].plot(np.arange(start_seq,end_seq), train_data[start_seq:end_seq,  i], 
                 color='grey', ls='-', lw=1.5, zorder=1)

    axes[i].set_xlabel('Time', fontsize = 15)
    axes[i].set_ylabel('Value', fontsize = 15)
    axes[i].grid(color='blue', which='major', linestyle=':',linewidth=0.5)

# %% [markdown]
# ### Dataset

# %%
class NominalDataset(Dataset):

	def __init__(self, x: np.array, seq_length: int, step: int):
		super(NominalDataset, self).__init__()

		if not isinstance(x, np.ndarray):
			raise Exception("X isn't numpy.ndarray ")

		self.n_samples = x.shape[0] - step * (seq_length - 1) - 1
		self.data = [
			(
				torch.from_numpy(x[i:i+(seq_length*step):step, :].astype(np.float32)),
				torch.from_numpy(x[i+((seq_length-1)*step)+1, :].astype(np.float32))
			)

			for i in range(self.n_samples)
		]
	

	def __getitem__(self, index: int) -> tuple:
		return self.data[index][0], self.data[index][1]


	def __len__(self) -> int:
		return self.n_samples

# %% [markdown]
# ### Models

# %%
class Encoder(nn.Module):

	def __init__(self, input_size: int, hidden_size: int, 
				num_layers: int, seq_length: int, z_size: int):
		super(Encoder, self).__init__()

		self.z_size = z_size
		self.num_layers = num_layers
		self.hidden_size = hidden_size

		self.lstm = nn.LSTM(input_size, hidden_size, num_layers, 
							batch_first=True, bidirectional=True)

		# mu
		self.m_layers = nn.ModuleList([

			nn.Sequential(

				nn.Linear(2*hidden_size, hidden_size),
				nn.LeakyReLU(0.1),
				nn.Linear(hidden_size, z_size)

			)

			for _ in range(seq_length)
		])

		# logvar
		self.v_layers = nn.ModuleList([ 

			nn.Sequential(

				nn.Linear(2*hidden_size, hidden_size),
				nn.LeakyReLU(0.1),
				nn.Linear(hidden_size, z_size)

			)

			for _ in range(seq_length)
			])


	def forward(self, x: torch.tensor) -> torch.tensor:

		h0 = torch.zeros(2 * self.num_layers, x.size(0), self.hidden_size)
		c0 = torch.zeros(2 * self.num_layers, x.size(0), self.hidden_size)

		output, _ = self.lstm(x, (h0, c0))
		z = torch.zeros(x.size(0), x.size(1), self.z_size)

		mu = torch.zeros(x.size(0), x.size(1), self.z_size)
		logvar = torch.zeros(x.size(0), x.size(1), self.z_size)

		for indx, (m, v) in enumerate(zip(self.m_layers, self.v_layers)):
			mu[:, indx, :]  = m(output[:, indx, :])
			logvar[:, indx, :] = F.softplus(v(output[:, indx, :]))

			# reparametrazation trick
			std = torch.exp(logvar[:, indx, :] / 2)
			eps = torch.randn_like(std)

			z[:, indx, :] = mu[:, indx, :] + eps*std

		return z, mu, logvar

# %%
class Decoder(nn.Module):

	def __init__(self, z_size:  int, hidden_size: int, 
				num_layers: int, seq_length: int, output_size: int):
		super(Decoder, self).__init__()

		self.num_layers = num_layers
		self.output_size = output_size
		self.hidden_size = hidden_size

		self.lstm = nn.LSTM(z_size, hidden_size, num_layers, 
							batch_first=True, bidirectional=True)


		self.layers = nn.ModuleList([
			nn.Sequential(

				nn.Linear(hidden_size * 2, hidden_size),
				nn.LeakyReLU(0.2)

			)

			for _ in range(seq_length)

		])


		self.h2 = output_size * 2
		self.h4 = output_size * 4

		self.m = nn.Sequential(

			nn.Flatten(),
			nn.Linear(
				seq_length * hidden_size, 
				seq_length * hidden_size, bias=False
			),
			nn.LeakyReLU(0.2),
			nn.BatchNorm1d(seq_length * hidden_size),

			nn.Linear(
				seq_length * hidden_size, 
				seq_length * self.h4, bias=False
			),
			nn.LeakyReLU(0.2),
			nn.BatchNorm1d(seq_length * self.h4),

			nn.Linear(
				seq_length * self.h4, 
				seq_length * output_size
				)

		)

	
	def forward(self, z: torch.tensor) -> torch.tensor:

		h0 = torch.zeros(2*self.num_layers, z.size(0), self.hidden_size)
		c0 = torch.zeros(2*self.num_layers, z.size(0), self.hidden_size)

		output, _ = self.lstm(z, (h0, c0))
		hidden = torch.zeros(z.size(0), z.size(1), self.hidden_size)

		for indx, m in enumerate(self.layers):
			hidden[:, indx, :] = m(output[:, indx, :])

		x_recon = self.m(hidden)

		return x_recon.view(z.size(0), z.size(1), -1)

# %%
class VAE(nn.Module):

	def __init__(self, encoder, decoder):
		super(VAE, self).__init__()

		self.enc = encoder
		self.dec = decoder

	def forward(self, x: torch.tensor) -> tuple:

		z, mu, logvar = self.enc(x)
		x_recon = self.dec(z)

		return x_recon, mu, logvar

# %% [markdown]
# ### Hyperparameters

# %%
# Hyperparameters

INPUT_SIZE  = 2
OUTPUT_SIZE = 2
Z_SIZE = 3

STEP = 1
SEQ_LENGTH = 100
BATCH_SIZE = 64

# %%
# Dataset
dataset = NominalDataset(train_data, seq_length=SEQ_LENGTH, step=STEP)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
# part of VAE
encoder = Encoder(
    
    input_size=INPUT_SIZE, 
    hidden_size=80, 
    num_layers=1, 
    seq_length=SEQ_LENGTH, 
    z_size=Z_SIZE

)

decoder = Decoder(
    
    z_size=Z_SIZE, 
    hidden_size=80, 
    num_layers=1, 
    seq_length=SEQ_LENGTH, 
    output_size=OUTPUT_SIZE

)

model = VAE(encoder, decoder)

# %%
def vae_loss(recon_x, x, mu, logvar, landa = 1):
    
    likelihood = F.mse_loss(x_recon, x, reduction='none').mean(0)
    KLD = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp(), dim=0)
    
    return torch.sum(likelihood), torch.sum(KLD)

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[10,25], gamma=0.1)

# %% [markdown]
# ### Training Loop

# %%
LANDA = 1
for epoch in range(30):
    
    mu_values  = torch.tensor([])
    var_values = torch.tensor([])    
        
    KLDLosses = torch.tensor([])
    likelihoodLosses = torch.tensor([])

    
    for sample, target in dataloader:
        
        x_recon, mu, logvar = model(sample)

        mu_values   = torch.cat((mu_values,  torch.mean(mu, dim=2)), dim=0)
        var_values  = torch.cat((var_values, torch.mean(logvar.exp(), dim=2)), dim=0)
        
    
        #VAE train
        
        likelihood, KLD = vae_loss(x_recon, sample, mu, logvar, LANDA)
        loss = likelihood + KLD

        KLDLosses = torch.cat(
            (KLDLosses, torch.unsqueeze(KLD, 0)), dim=0
        )
        
        likelihoodLosses = torch.cat(
            (likelihoodLosses, torch.unsqueeze(likelihood, 0)), dim=0
        )

        model.zero_grad()
        loss.backward()

        # cliping
        torch.nn.utils.clip_grad_norm_(
            model.parameters(), max_norm=1, norm_type=2
        )

        optimizer.step()
    
    scheduler.step()
    print("""    \nEpoch {}: LikeliHood: {:.5f}, KLD: {:.5f}
    Mean: [{}\n\t   {}] 
    Var:  [{}\n\t   {}]""".format(epoch, torch.mean(likelihoodLosses), torch.mean(KLDLosses),
                                  torch.mean(mu_values, dim=0)[:5].detach(), torch.mean(mu_values, dim=0)[-5:].detach(),
                                  torch.mean(var_values, dim=0)[:5].detach(), torch.mean(var_values, dim=0)[-5:].detach()
    ))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-80-98c89e38bb89> in <module>
#      11     for sample, target in dataloader:
#      12
# ---> 13         x_recon, mu, logvar = model(sample)
#      14
#      15         mu_values   = torch.cat((mu_values,  torch.mean(mu, dim=2)), dim=0)
#
# ~/Documents/VAE-SPOT/env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-67-2d9017b8502d> in forward(self, x)
#      10
#      11                 z, mu, logvar = self.enc(x)
# ---> 12                 x_recon = self.dec(z)
#      13
#      14                 return x_recon, mu, logvar
#
# ~/Documents/VAE-SPOT/env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-66-9acd7dc40d89> in forward(self, z)
#      59                 c0 = torch.zeros(2*self.num_layers, z.size(0), self.hidden_size)
#      60
# ---> 61                 output, _ = self.lstm(z, (h0, c0))
#      62                 hidden = torch.zeros(z.size(0), z.size(1), self.hidden_size)
#      63
#
# ~/Documents/VAE-SPOT/env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Documents/VAE-SPOT/env/lib/python3.8/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     657             hx = self.permute_hidden(hx, sorted_indices)
#     658
# --> 659         self.check_forward_args(input, hx, batch_sizes)
#     660         if batch_sizes is None:
#     661             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#
# ~/Documents/VAE-SPOT/env/lib/python3.8/site-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     604     def check_forward_args(self, input: Tensor, hidden: Tuple[Tensor, Tensor], batch_sizes: Optional[Tensor]):  # type: ignore
#     605         self.check_input(input, batch_sizes)
# --> 606         self.check_hidden_size(hidden[0], self.get_expected_hidden_size(input, batch_sizes),
#     607                                'Expected hidden[0] size {}, got {}')
#     608         self.check_hidden_size(hidden[1], self.get_expected_cell_size(input, batch_sizes),
#
# ~/Documents/VAE-SPOT/env/lib/python3.8/site-packages/torch/nn/modules/rnn.py in check_hidden_size(self, hx, expected_hidden_size, msg)
#     221                           msg: str = 'Expected hidden size {}, got {}') -> None:
#     222         if hx.size() != expected_hidden_size:
# --> 223             raise RuntimeError(msg.format(expected_hidden_size, list(hx.size())))
#     224
#     225     def check_forward_args(self, input: Tensor, hidden: Tensor, batch_sizes: Optional[Tensor]):
#
# RuntimeError: Expected hidden[0] size (2, 64, 3), got [2, 64, 80]
